# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
 df = df[['Pclass','Survived','Sex','Age','Fare']]

df
# Out:
#      Pclass  Survived     Sex   Age     Fare
# 0         3         0    male  22.0   7.2500
# 1         1         1  female  38.0  71.2833
# 2         3         1  female  26.0   7.9250
# 3         1         1  female  35.0  53.1000
# 4         3         0    male  35.0   8.0500
# ..      ...       ...     ...   ...      ...
# 886       2         0    male  27.0  13.0000
# 887       1         1  female  19.0  30.0000
# 888       3         0  female   NaN  23.4500
# 889       1         1    male  26.0  30.0000
# 890       3         0    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
df['Sex'] = df['Sex'].map({'male':0,'female':1})
# Out:
# /var/folders/6q/3nz6q5cj4yldckb8m8_glpp80000gp/T/ipykernel_7143/2591550582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sex'] = df['Sex'].map({'male':0,'female':1})

# %%
df
# Out:
#      Pclass  Survived  Sex   Age     Fare
# 0         3         0    0  22.0   7.2500
# 1         1         1    1  38.0  71.2833
# 2         3         1    1  26.0   7.9250
# 3         1         1    1  35.0  53.1000
# 4         3         0    0  35.0   8.0500
# ..      ...       ...  ...   ...      ...
# 886       2         0    0  27.0  13.0000
# 887       1         1    1  19.0  30.0000
# 888       3         0    1   NaN  23.4500
# 889       1         1    0  26.0  30.0000
# 890       3         0    0  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
df.groupby('Survived').mean()
# Out:
#             Pclass       Sex        Age       Fare
# Survived
# 0         2.531876  0.147541  30.626179  22.117887
# 1         1.950292  0.681287  28.343690  48.395408

# %%
pd.crosstab(df.Sex,df.Survived).plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %%
df[df.isna().any(axis=1)]
# Out:
#      Pclass  Survived  Sex  Age     Fare
# 5         3         0    0  NaN   8.4583
# 17        2         1    0  NaN  13.0000
# 19        3         1    1  NaN   7.2250
# 26        3         0    0  NaN   7.2250
# 28        3         1    1  NaN   7.8792
# ..      ...       ...  ...  ...      ...
# 859       3         0    0  NaN   7.2292
# 863       3         0    1  NaN  69.5500
# 868       3         0    0  NaN   9.5000
# 878       3         0    0  NaN   7.8958
# 888       3         0    1  NaN  23.4500
#
# [177 rows x 5 columns]

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df[df.isna().any(axis=1)]
# Out:
# /var/folders/6q/3nz6q5cj4yldckb8m8_glpp80000gp/T/ipykernel_7143/3139214017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# Empty DataFrame
# Columns: [Pclass, Survived, Sex, Age, Fare]
# Index: []

# %%
df.Age = df.Age.round(2)
df
# Out:
# /var/folders/6q/3nz6q5cj4yldckb8m8_glpp80000gp/T/ipykernel_7143/3943871514.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Age = df.Age.round(2)
#      Pclass  Survived  Sex   Age     Fare
# 0         3         0    0  22.0   7.2500
# 1         1         1    1  38.0  71.2833
# 2         3         1    1  26.0   7.9250
# 3         1         1    1  35.0  53.1000
# 4         3         0    0  35.0   8.0500
# ..      ...       ...  ...   ...      ...
# 886       2         0    0  27.0  13.0000
# 887       1         1    1  19.0  30.0000
# 888       3         0    1  29.7  23.4500
# 889       1         1    0  26.0  30.0000
# 890       3         0    0  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
model = tree.DecisionTreeClassifier()

# %%
input_df = df.drop("Survived",axis=1)
input_df
# Out:
#      Pclass  Sex   Age     Fare
# 0         3    0  22.0   7.2500
# 1         1    1  38.0  71.2833
# 2         3    1  26.0   7.9250
# 3         1    1  35.0  53.1000
# 4         3    0  35.0   8.0500
# ..      ...  ...   ...      ...
# 886       2    0  27.0  13.0000
# 887       1    1  19.0  30.0000
# 888       3    1  29.7  23.4500
# 889       1    0  26.0  30.0000
# 890       3    0  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
target = df.Survived
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(input_df,target,test_size = 0.2)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.7877094972067039

# %%
model.score(X_train,y_train)
# Out:
# 0.9803370786516854

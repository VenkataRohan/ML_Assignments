# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('bank_churn_data.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
for col in df:
    print(f'{col} = {df[col].unique()}')
# Out:
# RowNumber = [    1     2     3 ...  9998  9999 10000]
# CustomerId = [15634602 15647311 15619304 ... 15584532 15682355 15628319]
# Surname = ['Hargrave' 'Hill' 'Onio' ... 'Kashiwagi' 'Aldridge' 'Burbidge']
# CreditScore = [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
# ...

# %%
df.drop(['CustomerId','Surname'],axis='columns',inplace=True)
df
# Out:
#       RowNumber  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0             1          619    France  Female   42       2       0.00
# 1             2          608     Spain  Female   41       1   83807.86
# 2             3          502    France  Female   42       8  159660.80
# 3             4          699    France  Female   39       1       0.00
# 4             5          850     Spain  Female   43       2  125510.82
# ...         ...          ...       ...     ...  ...     ...        ...
# 9995       9996          771    France    Male   39       5       0.00
# 9996       9997          516    France    Male   35      10   57369.61
# 9997       9998          709    France  Female   36       7       0.00
# 9998       9999          772   Germany    Male   42       3   75075.31
# 9999      10000          792    France  Female   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df[df['CreditScore'].isnull()]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
for col in df:
    print(f'{col} = {df[df[col].isnull()]}')
# Out:
# RowNumber = Empty DataFrame
# Columns: [RowNumber, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []
# CreditScore = Empty DataFrame
# Columns: [RowNumber, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []
# Geography = Empty DataFrame
# Columns: [RowNumber, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []
# Gender = Empty DataFrame
# Columns: [RowNumber, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []
# Age = Empty DataFrame
# Columns: [RowNumber, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []
# Tenure = Empty DataFrame
# ...

# %%
df.dtypes
# Out:
# RowNumber            int64
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df
# Out:
#       RowNumber  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0             1          619    France  Female   42       2       0.00
# 1             2          608     Spain  Female   41       1   83807.86
# 2             3          502    France  Female   42       8  159660.80
# 3             4          699    France  Female   39       1       0.00
# 4             5          850     Spain  Female   43       2  125510.82
# ...         ...          ...       ...     ...  ...     ...        ...
# 9995       9996          771    France    Male   39       5       0.00
# 9996       9997          516    France    Male   35      10   57369.61
# 9997       9998          709    France  Female   36       7       0.00
# 9998       9999          772   Germany    Male   42       3   75075.31
# 9999      10000          792    France  Female   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
tenure_churn_no = df[df.Exited==1].Tenure
tenure_churn_yes = df[df.Exited==0].Tenure

plt.xlabel("Tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['red','green'],label=['Exited=Yes','Exited=No'])
plt.legend()

# %%
df['Gender'].replace({'Female':1,'Male':0},inplace=True)
df['Gender']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    0
# 9999    1
# Name: Gender, Length: 10000, dtype: int64

# %%
df1 = pd.get_dummies(df, 'Geography', drop_first=True,dtype=int)
df1.columns
# Out:
# Index(['RowNumber', 'CreditScore', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited', 'Geography_Germany', 'Geography_Spain'],
#       dtype='object')

# %%
df1
# Out:
#       RowNumber  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             1          619       1   42       2       0.00              1
# 1             2          608       1   41       1   83807.86              1
# 2             3          502       1   42       8  159660.80              3
# 3             4          699       1   39       1       0.00              2
# 4             5          850       1   43       2  125510.82              1
# ...         ...          ...     ...  ...     ...        ...            ...
# 9995       9996          771       0   39       5       0.00              2
# 9996       9997          516       0   35      10   57369.61              1
# 9997       9998          709       1   36       7       0.00              1
# 9998       9999          772       0   42       3   75075.31              2
# 9999      10000          792       1   28       4  130142.79              1
#
# ...

# %%
cols_to_scale = ['CreditScore','Balance','EstimatedSalary','Age','Tenure','NumOfProducts']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df1[cols_to_scale] = scaler.fit_transform(df1[cols_to_scale])

# %%
df1.drop('RowNumber',inplace=True,axis =1)

# %%
df1
# Out:
#       CreditScore  Gender       Age  Tenure   Balance  NumOfProducts  \
# 0           0.538       1  0.324324     0.2  0.000000       0.000000
# 1           0.516       1  0.310811     0.1  0.334031       0.000000
# 2           0.304       1  0.324324     0.8  0.636357       0.666667
# 3           0.698       1  0.283784     0.1  0.000000       0.333333
# 4           1.000       1  0.337838     0.2  0.500246       0.000000
# ...           ...     ...       ...     ...       ...            ...
# 9995        0.842       0  0.283784     0.5  0.000000       0.333333
# 9996        0.332       0  0.229730     1.0  0.228657       0.000000
# 9997        0.718       1  0.243243     0.7  0.000000       0.000000
# 9998        0.844       0  0.324324     0.3  0.299226       0.333333
# 9999        0.884       1  0.135135     0.4  0.518708       0.000000
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# ...

# %%
for col in df1:
    print(f'{col} = {df1[col].unique()}')
# Out:
# CreditScore = [0.538 0.516 0.304 0.698 1.    0.59  0.944 0.052 0.302 0.668 0.356 0.294
#  0.252 0.398 0.57  0.532 0.606 0.474 0.752 0.764 0.572 0.32  0.638 0.992
#  0.454 0.812 0.442 0.448 0.122 0.482 0.366 0.406 0.34  0.744 0.25  0.28
#  0.908 0.464 0.244 0.23  0.412 0.968 0.62  0.852 0.958 0.574 0.4   0.696
#  0.47  0.876 0.61  0.502 0.612 0.75  0.322 0.528 0.784 0.674 0.41  0.506
#  0.802 0.462 0.77  0.622 0.65  0.776 0.926 0.614 0.508 0.338 0.628 0.656
#  0.814 0.132 0.63  0.854 0.386 0.312 0.286 0.604 0.8   0.758 0.592 0.594
#  0.916 0.348 0.838 0.76  0.33  0.846 0.928 0.72  0.126 0.546 0.64  0.544
#  0.87  0.51  0.258 0.67  0.376 0.424 0.742 0.556 0.636 0.956 0.648 0.55
#  0.164 0.84  0.816 0.89  0.672 0.878 0.478 0.222 0.468 0.458 0.626 0.664
#  0.886 0.682 0.27  0.6   0.808 0.37  0.732 0.378 0.712 0.472 0.562 0.734
#  0.9   0.666 0.708 0.53  0.634 0.268 0.26  0.456 0.324 0.512 0.494 0.856
#  0.328 0.35  0.73  0.46  0.914 0.342 0.818 0.332 0.722 0.536 0.586 0.642
# ...

# %%
X = df1.drop('Exited',axis = 1)
y = df1.Exited

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(11,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 250/250 [==============================] - 0s 403us/step - loss: 0.5094 - accuracy: 0.7899
# Epoch 2/500
# 250/250 [==============================] - 0s 399us/step - loss: 0.4607 - accuracy: 0.8009
# Epoch 3/500
# 250/250 [==============================] - 0s 383us/step - loss: 0.4415 - accuracy: 0.8131
# Epoch 4/500
# 250/250 [==============================] - 0s 395us/step - loss: 0.4251 - accuracy: 0.8185
# Epoch 5/500
# 250/250 [==============================] - 0s 395us/step - loss: 0.4137 - accuracy: 0.8215
# Epoch 6/500
# 250/250 [==============================] - 0s 390us/step - loss: 0.4013 - accuracy: 0.8255
# Epoch 7/500
# 250/250 [==============================] - 0s 397us/step - loss: 0.3903 - accuracy: 0.8298
# Epoch 8/500
# 250/250 [==============================] - 0s 387us/step - loss: 0.3796 - accuracy: 0.8357
# Epoch 9/500
# 250/250 [==============================] - 0s 389us/step - loss: 0.3718 - accuracy: 0.8400
# Epoch 10/500
# ...
